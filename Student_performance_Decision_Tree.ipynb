# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\H P\Downloads\xAPI-Edu-Data.csv")
data
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                  16                  2          20                     Good
# 1                  20                  3          25                     Good
# 2                   7                  0          30                      Bad
# 3                  25                  5          35                      Bad
# 4                  50                 12          50                      Bad
# ..                ...                ...         ...                      ...
# 475                 4                  5           8                      Bad
# 476                77                 14          28                      Bad
# 477                74                 25          29                      Bad
# 478                17                 14          57                      Bad
# 479                14                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 13 columns]

# %%
data.describe(include='all')
# Out:
#        gender       StageID SectionID Relation Semester Topic  raisedhands  \
# count     480           480       480      480      480   480   480.000000
# unique      2             3         3        2        2    12          NaN
# top         M  MiddleSchool         A   Father        F    IT          NaN
# freq      305           248       283      283      245    95          NaN
# mean      NaN           NaN       NaN      NaN      NaN   NaN    46.775000
# std       NaN           NaN       NaN      NaN      NaN   NaN    30.779223
# min       NaN           NaN       NaN      NaN      NaN   NaN     0.000000
# 25%       NaN           NaN       NaN      NaN      NaN   NaN    15.750000
# 50%       NaN           NaN       NaN      NaN      NaN   NaN    50.000000
# 75%       NaN           NaN       NaN      NaN      NaN   NaN    75.000000
# max       NaN           NaN       NaN      NaN      NaN   NaN   100.000000
#
#         VisITedResources  AnnouncementsView  Discussion  \
# count         480.000000         480.000000  480.000000
# unique               NaN                NaN         NaN
# top                  NaN                NaN         NaN
# freq                 NaN                NaN         NaN
# mean           54.797917          37.918750   43.283333
# std            33.080007          26.611244   27.637735
# min             0.000000           0.000000    1.000000
# 25%            20.000000          14.000000   20.000000
# 50%            65.000000          33.000000   39.000000
# 75%            84.000000          58.000000   70.000000
# max            99.000000          98.000000   99.000000
#
#        ParentschoolSatisfaction StudentAbsenceDays Class
# count                       480                480   480
# unique                        2                  2     3
# top                        Good            Under-7     M
# freq                        292                289   211
# mean                        NaN                NaN   NaN
# std                         NaN                NaN   NaN
# min                         NaN                NaN   NaN
# 25%                         NaN                NaN   NaN
# 50%                         NaN                NaN   NaN
# 75%                         NaN                NaN   NaN
# max                         NaN                NaN   NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   StageID                   480 non-null    object
#  2   SectionID                 480 non-null    object
#  3   Relation                  480 non-null    object
#  4   Semester                  480 non-null    object
#  5   Topic                     480 non-null    object
#  6   raisedhands               480 non-null    int64
#  7   VisITedResources          480 non-null    int64
#  8   AnnouncementsView         480 non-null    int64
#  9   Discussion                480 non-null    int64
#  10  ParentschoolSatisfaction  480 non-null    object
#  11  StudentAbsenceDays        480 non-null    object
#  12  Class                     480 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 48.9+ KB

# %%
data.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# SectionID                   0
# Relation                    0
# Semester                    0
# Topic                       0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
for i in data.columns:
    print({i:data[i].unique()})
# Out:
# {'gender': array(['M', 'F'], dtype=object)}
# {'StageID': array(['lowerlevel', 'MiddleSchool', 'HighSchool'], dtype=object)}
# {'SectionID': array(['A', 'B', 'C'], dtype=object)}
# {'Relation': array(['Father', 'Mum'], dtype=object)}
# {'Semester': array(['F', 'S'], dtype=object)}
# {'Topic': array(['IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
#        'French', 'History', 'Biology', 'Chemistry', 'Geology'],
#       dtype=object)}
# {'raisedhands': array([ 15,  20,  10,  30,  40,  42,  35,  50,  12,  70,  19,   5,  62,
#         36,  55,  69,  60,   2,   0,   8,  25,  75,   4,  45,  14,  33,
#          7,  13,  29,  39,  49,  16,  28,  27,  21,  80,  17,  65,  22,
#         11,   1,   3, 100,   6,  90,  77,  24,  66,  23,  82,  72,  51,
#         85,  87,  95,  81,  53,  92,  83,  67,  96,  57,  73,   9,  32,
#         52,  59,  61,  79,  18,  74,  97,  41,  71,  98,  78,  89,  88,
#         86,  76,  99,  84])}
# {'VisITedResources': array([16, 20,  7, 25, 50, 30, 12, 10, 21, 80, 88,  6,  1, 14, 70, 40, 13,
#        15, 60,  0,  2, 19, 85, 90,  5, 22, 11, 54, 35, 33,  4, 39, 75, 69,
#         3,  8, 89, 44, 92, 26, 27, 29, 98,  9, 42, 65, 79, 55, 63, 91, 51,
#        58, 68, 82, 72, 52, 62, 71, 66, 43, 95, 31, 41, 81, 61, 83, 84, 17,
#        94, 48, 86, 74, 76, 97, 87, 99, 34, 64, 28, 38, 36, 24, 59, 57, 77,
#        18, 93, 96, 78])}
# {'AnnouncementsView': array([ 2,  3,  0,  5, 12, 13, 15, 16, 25, 30, 19, 44, 22, 20, 35, 36, 40,
#        33,  4, 52, 50, 10,  9,  8, 17, 26, 37,  7, 28,  1, 39,  6, 32, 70,
#        18, 23, 11, 29, 49, 55, 38, 41, 51, 95, 85, 71, 98, 73, 48, 58, 93,
#        83, 53, 63, 62, 82, 72, 42, 46, 77, 21, 88, 66, 86, 80, 56, 91, 65,
#        76, 24, 74, 59, 79, 34, 69, 89, 31, 60, 54, 57, 64, 87, 75, 67, 43,
#        45, 14, 78])}
# {'Discussion': array([20, 25, 30, 35, 50, 70, 17, 22, 80, 12, 11, 19, 60, 66, 90, 96, 99,
#        40, 33, 43, 16,  4, 88, 77, 75,  1,  5,  2,  8, 13, 44,  9, 55, 10,
#        15,  7,  3, 14, 69, 59, 89, 41, 91, 49, 73, 23, 53, 93, 51, 83, 24,
#        84, 61, 94, 34, 81, 29, 46, 26,  6, 76, 86, 85, 65, 95, 64, 32, 37,
#        36, 27, 39, 74, 79, 21, 31, 28, 38, 48, 97, 98, 63, 72, 82, 71, 45,
#        68, 92, 58, 57, 62])}
# {'ParentschoolSatisfaction': array(['Good', 'Bad'], dtype=object)}
# {'StudentAbsenceDays': array(['Under-7', 'Above-7'], dtype=object)}
# {'Class': array(['M', 'L', 'H'], dtype=object)}

# %%
data.Topic.value_counts()
# Out:
# Topic
# IT           95
# French       65
# Arabic       59
# Science      51
# English      45
# Biology      30
# Spanish      25
# Geology      24
# Chemistry    24
# Quran        22
# Math         21
# History      19
# Name: count, dtype: int64

# %%
data['Institute']='XYZ'
data
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                  16                  2          20                     Good
# 1                  20                  3          25                     Good
# 2                   7                  0          30                      Bad
# 3                  25                  5          35                      Bad
# 4                  50                 12          50                      Bad
# ..                ...                ...         ...                      ...
# 475                 4                  5           8                      Bad
# 476                77                 14          28                      Bad
# 477                74                 25          29                      Bad
# 478                17                 14          57                      Bad
# 479                14                 23          62                      Bad
#
#     StudentAbsenceDays Class Institute
# 0              Under-7     M       XYZ
# 1              Under-7     M       XYZ
# 2              Above-7     L       XYZ
# 3              Above-7     L       XYZ
# 4              Above-7     M       XYZ
# ..                 ...   ...       ...
# 475            Above-7     L       XYZ
# 476            Under-7     M       XYZ
# 477            Under-7     M       XYZ
# 478            Above-7     L       XYZ
# 479            Above-7     L       XYZ
#
# [480 rows x 14 columns]

# %% [markdown]
# # Feature Selection:

# %%
# Feature selection based on singularity and cardinality
data.columns
# Out:
# Index(['gender', 'StageID', 'SectionID', 'Relation', 'Semester', 'Topic',
#        'raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Class', 'Institute'],
#       dtype='object')

# %%
data
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                  16                  2          20                     Good
# 1                  20                  3          25                     Good
# 2                   7                  0          30                      Bad
# 3                  25                  5          35                      Bad
# 4                  50                 12          50                      Bad
# ..                ...                ...         ...                      ...
# 475                 4                  5           8                      Bad
# 476                77                 14          28                      Bad
# 477                74                 25          29                      Bad
# 478                17                 14          57                      Bad
# 479                14                 23          62                      Bad
#
#     StudentAbsenceDays Class Institute
# 0              Under-7     M       XYZ
# 1              Under-7     M       XYZ
# 2              Above-7     L       XYZ
# 3              Above-7     L       XYZ
# 4              Above-7     M       XYZ
# ..                 ...   ...       ...
# 475            Above-7     L       XYZ
# 476            Under-7     M       XYZ
# 477            Under-7     M       XYZ
# 478            Above-7     L       XYZ
# 479            Above-7     L       XYZ
#
# [480 rows x 14 columns]

# %%
### Dropping institute columns as it has singularity
data.drop(['Institute'],axis=1,inplace=True)           # axis=1 is relate column, axis=0 is relate row

# %%
data
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                  16                  2          20                     Good
# 1                  20                  3          25                     Good
# 2                   7                  0          30                      Bad
# 3                  25                  5          35                      Bad
# 4                  50                 12          50                      Bad
# ..                ...                ...         ...                      ...
# 475                 4                  5           8                      Bad
# 476                77                 14          28                      Bad
# 477                74                 25          29                      Bad
# 478                17                 14          57                      Bad
# 479                14                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 13 columns]

# %%
# Dropping 'SectionID','Semester' based on domain knowledge 
data.drop(['SectionID','Semester'],axis=1,inplace=True)

# %%
data
# Out:
#     gender       StageID Relation      Topic  raisedhands  VisITedResources  \
# 0        M    lowerlevel   Father         IT           15                16
# 1        M    lowerlevel   Father         IT           20                20
# 2        M    lowerlevel   Father         IT           10                 7
# 3        M    lowerlevel   Father         IT           30                25
# 4        M    lowerlevel   Father         IT           40                50
# ..     ...           ...      ...        ...          ...               ...
# 475      F  MiddleSchool   Father  Chemistry            5                 4
# 476      F  MiddleSchool   Father    Geology           50                77
# 477      F  MiddleSchool   Father    Geology           55                74
# 478      F  MiddleSchool   Father    History           30                17
# 479      F  MiddleSchool   Father    History           35                14
#
#      AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                    2          20                     Good
# 1                    3          25                     Good
# 2                    0          30                      Bad
# 3                    5          35                      Bad
# 4                   12          50                      Bad
# ..                 ...         ...                      ...
# 475                  5           8                      Bad
# 476                 14          28                      Bad
# 477                 25          29                      Bad
# 478                 14          57                      Bad
# 479                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 11 columns]

# %%
# Dropping feature 'Topic' on the basis of domain knowledge & high cardinality
data.drop('Topic',axis=1,inplace=True)

# %%
data
# Out:
#     gender       StageID Relation  raisedhands  VisITedResources  \
# 0        M    lowerlevel   Father           15                16
# 1        M    lowerlevel   Father           20                20
# 2        M    lowerlevel   Father           10                 7
# 3        M    lowerlevel   Father           30                25
# 4        M    lowerlevel   Father           40                50
# ..     ...           ...      ...          ...               ...
# 475      F  MiddleSchool   Father            5                 4
# 476      F  MiddleSchool   Father           50                77
# 477      F  MiddleSchool   Father           55                74
# 478      F  MiddleSchool   Father           30                17
# 479      F  MiddleSchool   Father           35                14
#
#      AnnouncementsView  Discussion ParentschoolSatisfaction  \
# 0                    2          20                     Good
# 1                    3          25                     Good
# 2                    0          30                      Bad
# 3                    5          35                      Bad
# 4                   12          50                      Bad
# ..                 ...         ...                      ...
# 475                  5           8                      Bad
# 476                 14          28                      Bad
# 477                 25          29                      Bad
# 478                 14          57                      Bad
# 479                 23          62                      Bad
#
#     StudentAbsenceDays Class
# 0              Under-7     M
# 1              Under-7     M
# 2              Above-7     L
# 3              Above-7     L
# 4              Above-7     M
# ..                 ...   ...
# 475            Above-7     L
# 476            Under-7     M
# 477            Under-7     M
# 478            Above-7     L
# 479            Above-7     L
#
# [480 rows x 10 columns]

# %% [markdown]
# # EDA

# %%
data.dtypes
# Out:
# gender                      object
# StageID                     object
# Relation                    object
# raisedhands                  int64
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
# Histogram helps to understand the frequency distribution of single continous numeric feature
data.hist(figsize=(15,7));     # 15,7 is graph size

# %%
# In the above histogram x-axis defines the frequency number of a student activity on a perticular attribute
 # and y-axis  defines the counts.
* majority students perform visiting resource 
* majority of the students are less eager to view announcement & to discussion groups
* an average situation arise in case of the hand raising
# Out:
#   Cell In[38], line 3
#     * majority students perform visiting resource
#                ^
# SyntaxError: invalid syntax

# %%
data.columns

# %%
feature=['raisedhands','VisITedResources','AnnouncementsView','Discussion']

# %%
sns.pairplot(x_vars=feature,y_vars=feature,data=data,hue='Class')

# %% [markdown]
# ''' from the above pair plot it is quit a lot clear to see high and low-level students are distinguishable in every combination of pair plot but medium level students are scattered in almost everywhere and mixed up both high and low level '''

# %% [markdown]
# # Visualization of categorical data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(data=data,x='gender',hue='Class',palette='viridis')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# ''' though the number of male students is greater than the female but the percentage of high level students are less than on the other hand , low level students in the male are quite a lot greater than the female students. '''

# %%
sns.countplot(data=data,x='Relation',hue='Class',palette='Set1')
# Out:
# <Axes: xlabel='Relation', ylabel='count'>

# %%
sns.countplot(data=data,x='StudentAbsenceDays',hue='Class',palette='Set2')
# Out:
# <Axes: xlabel='StudentAbsenceDays', ylabel='count'>

# %% [markdown]
# ''' The above picture clearly states that the student who is absent less than 7 days is mostly the succesful one .It means students absence '''

# %%
data.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
data.Class.value_counts()
# Out:
# Class
# M    211
# H    142
# L    127
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
sns.countplot(data=data,x='Class',palette='pastel')
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
colname=[]
for x in data.columns:
    if data[x].dtype=='object':
        colname.append(x)
colname
# Out:
# ['gender',
#  'StageID',
#  'Relation',
#  'ParentschoolSatisfaction',
#  'StudentAbsenceDays',
#  'Class']

# %%
# For preprocessing the data
from sklearn.preprocessing import LabelEncoder
 
le=LabelEncoder()
 
for x in colname[:-1]:
    data[x]=le.fit_transform(data[x])
 
    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print('Feature', x)
    print('mapping', le_name_mapping)
    print('-----------------------')
# Out:
# Feature gender
# mapping {'F': np.int64(0), 'M': np.int64(1)}
# -----------------------
# Feature StageID
# mapping {'HighSchool': np.int64(0), 'MiddleSchool': np.int64(1), 'lowerlevel': np.int64(2)}
# -----------------------
# Feature Relation
# mapping {'Father': np.int64(0), 'Mum': np.int64(1)}
# -----------------------
# Feature ParentschoolSatisfaction
# mapping {'Bad': np.int64(0), 'Good': np.int64(1)}
# -----------------------
# Feature StudentAbsenceDays
# mapping {'Above-7': np.int64(0), 'Under-7': np.int64(1)}
# -----------------------

# %%
data
# Out:
#      gender  StageID  Relation  raisedhands  VisITedResources  \
# 0         1        2         0           15                16
# 1         1        2         0           20                20
# 2         1        2         0           10                 7
# 3         1        2         0           30                25
# 4         1        2         0           40                50
# ..      ...      ...       ...          ...               ...
# 475       0        1         0            5                 4
# 476       0        1         0           50                77
# 477       0        1         0           55                74
# 478       0        1         0           30                17
# 479       0        1         0           35                14
#
#      AnnouncementsView  Discussion  ParentschoolSatisfaction  \
# 0                    2          20                         1
# 1                    3          25                         1
# 2                    0          30                         0
# 3                    5          35                         0
# 4                   12          50                         0
# ..                 ...         ...                       ...
# 475                  5           8                         0
# 476                 14          28                         0
# 477                 25          29                         0
# 478                 14          57                         0
# 479                 23          62                         0
#
#      StudentAbsenceDays Class
# 0                     1     M
# 1                     1     M
# 2                     0     L
# 3                     0     L
# 4                     0     M
# ..                  ...   ...
# 475                   0     L
# 476                   1     M
# 477                   1     M
# 478                   0     L
# 479                   0     L
#
# [480 rows x 10 columns]

# %%
# class follow an ordinal approach for classes so we will try to encode it manually 
data['Class']=data['Class'].map({'L':0,'M':1,'H':2})

# %%
data
# Out:
#      gender  StageID  Relation  raisedhands  VisITedResources  \
# 0         1        2         0           15                16
# 1         1        2         0           20                20
# 2         1        2         0           10                 7
# 3         1        2         0           30                25
# 4         1        2         0           40                50
# ..      ...      ...       ...          ...               ...
# 475       0        1         0            5                 4
# 476       0        1         0           50                77
# 477       0        1         0           55                74
# 478       0        1         0           30                17
# 479       0        1         0           35                14
#
#      AnnouncementsView  Discussion  ParentschoolSatisfaction  \
# 0                    2          20                         1
# 1                    3          25                         1
# 2                    0          30                         0
# 3                    5          35                         0
# 4                   12          50                         0
# ..                 ...         ...                       ...
# 475                  5           8                         0
# 476                 14          28                         0
# 477                 25          29                         0
# 478                 14          57                         0
# 479                 23          62                         0
#
#      StudentAbsenceDays  Class
# 0                     1      1
# 1                     1      1
# 2                     0      0
# 3                     0      0
# 4                     0      1
# ..                  ...    ...
# 475                   0      0
# 476                   1      1
# 477                   1      1
# 478                   0      0
# 479                   0      0
#
# [480 rows x 10 columns]

# %%
sns.set()
Class_plot=data['Class'].value_counts().plot(kind='bar')
plt.xlabel('Performance')
plt.ylabel('Count')
plt.xticks(rotation=360)
plt.show()

# %%
data['Class'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.ylabel(' ');

# %%
X=data.values[:,0:-1]
Y=data.values[:,-1]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (480, 9)
# (480,)

# %%
from sklearn.preprocessing import StandardScaler
 
scaler = StandardScaler()
 
scaler.fit(X)
X = scaler.transform(X)
#X=scaler.fit_transform(X)
#print(X)

# %%
print(X)
# Out:
# [[ 0.7574764   1.08466911 -0.83433391 ... -0.84332615  0.80239368
#    0.81295735]
#  [ 0.7574764   1.08466911 -0.83433391 ... -0.66222533  0.80239368
#    0.81295735]
#  [ 0.7574764   1.08466911 -0.83433391 ... -0.48112451 -1.24627103
#   -1.23007683]
#  ...
#  [-1.32017315 -0.5734238  -0.83433391 ... -0.51734468 -1.24627103
#    0.81295735]
#  [-1.32017315 -0.5734238  -0.83433391 ...  0.49681992 -1.24627103
#   -1.23007683]
#  [-1.32017315 -0.5734238  -0.83433391 ...  0.67792074 -1.24627103
#   -1.23007683]]

# %%
from sklearn.model_selection import train_test_split
# Split the data into test and train 
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (384, 9)
# (384,)
# (96, 9)
# (96,)

# %%
from sklearn.linear_model import LogisticRegression
# create a model
classifier=LogisticRegression()
# fitting training data to the model
classifier.fit(X_train,Y_train)
Y_pred=classifier.predict(X_test)
Y_pred
# Out:
# array([2, 1, 1, 0, 2, 2, 2, 2, 1, 0, 1, 1, 2, 1, 1, 2, 0, 2, 1, 1, 0, 1,
#        1, 1, 1, 0, 2, 2, 1, 2, 2, 2, 0, 2, 1, 0, 1, 1, 0, 2, 1, 0, 1, 0,
#        1, 2, 2, 1, 1, 2, 1, 0, 2, 1, 1, 2, 2, 0, 1, 2, 2, 0, 2, 1, 1, 1,
#        1, 1, 0, 2, 1, 0, 1, 1, 1, 1, 0, 0, 2, 2, 0, 2, 0, 0, 1, 2, 1, 2,
#        2, 1, 2, 0, 1, 1, 2, 1])

# %%
np.set_printoptions(suppress=True)
Y_pred_prob=classifier.predict_proba(X_test)
Y_pred_prob
# Out:
# array([[0.00591701, 0.49434748, 0.4997355 ],
#        [0.07064708, 0.85718398, 0.07216894],
#        [0.14959046, 0.83346317, 0.01694638],
#        [0.62906019, 0.36218993, 0.00874988],
#        [0.00640642, 0.42250288, 0.5710907 ],
#        [0.0002327 , 0.18604789, 0.8137194 ],
#        [0.00302356, 0.29726439, 0.69971205],
#        [0.00130094, 0.39139404, 0.60730502],
#        [0.49239611, 0.50170139, 0.00590249],
#        [0.95449583, 0.04530733, 0.00019684],
#        [0.00138427, 0.62889304, 0.36972269],
#        [0.37392422, 0.59124773, 0.03482805],
#        [0.00499555, 0.48078095, 0.5142235 ],
#        [0.07371507, 0.66428315, 0.26200178],
#        [0.01197596, 0.71350876, 0.27451528],
#        [0.00390199, 0.48539436, 0.51070365],
#        [0.95306231, 0.04661094, 0.00032674],
#        [0.00145996, 0.30853298, 0.69000706],
#        [0.01196655, 0.87625951, 0.11177394],
#        [0.00395981, 0.59754493, 0.39849525],
#        [0.85182308, 0.14740519, 0.00077173],
#        [0.00263395, 0.84556788, 0.15179817],
#        [0.45962766, 0.521629  , 0.01874334],
#        [0.00101366, 0.55700096, 0.44198538],
#        [0.01493736, 0.8684537 , 0.11660894],
#        [0.94268299, 0.05702807, 0.00028894],
#        [0.00012445, 0.21441146, 0.78546409],
#        [0.00470384, 0.43570495, 0.5595912 ],
#        [0.01856877, 0.91087782, 0.07055341],
#        [0.00006965, 0.1523011 , 0.84762925],
#        [0.00125422, 0.49597525, 0.50277053],
#        [0.00108558, 0.33782138, 0.66109305],
#        [0.91493848, 0.08492764, 0.00013388],
#        [0.0029681 , 0.46111435, 0.53591755],
#        [0.00599551, 0.67463414, 0.31937035],
#        [0.87714477, 0.12186661, 0.00098862],
#        [0.00928193, 0.81281421, 0.17790386],
#        [0.04005908, 0.68812742, 0.2718135 ],
#        [0.71778246, 0.27641131, 0.00580623],
#        [0.00258267, 0.37345782, 0.62395951],
#        [0.01410913, 0.86773975, 0.11815112],
#        [0.79762298, 0.1991415 , 0.00323551],
#        [0.09392301, 0.62196574, 0.28411125],
#        [0.72971787, 0.265545  , 0.00473713],
#        [0.03262587, 0.73545558, 0.23191855],
#        [0.00044365, 0.4857254 , 0.51383095],
#        [0.00012184, 0.16559829, 0.83427987],
#        [0.00786281, 0.79632946, 0.19580773],
#        [0.09868527, 0.7963192 , 0.10499553],
#        [0.00052809, 0.32058227, 0.67888964],
#        [0.02727191, 0.80182373, 0.17090436],
#        [0.66964729, 0.3102321 , 0.02012061],
#        [0.00524604, 0.44840703, 0.54634693],
#        [0.02501825, 0.90291904, 0.07206271],
#        [0.00829211, 0.86945238, 0.12225551],
#        [0.00014186, 0.29392707, 0.70593107],
#        [0.00021443, 0.21924631, 0.78053926],
#        [0.89766129, 0.10125901, 0.0010797 ],
#        [0.01958834, 0.83242559, 0.14798608],
#        [0.00005237, 0.13335326, 0.86659437],
#        [0.00011135, 0.15247991, 0.84740874],
#        [0.92030716, 0.07931079, 0.00038205],
#        [0.00041915, 0.25332813, 0.74625272],
#        [0.07594259, 0.88418768, 0.03986972],
#        [0.42640361, 0.56508106, 0.00851533],
#        [0.03831804, 0.8043231 , 0.15735886],
#        [0.05060967, 0.79867718, 0.15071315],
#        [0.00012907, 0.64149861, 0.35837233],
#        [0.6801912 , 0.30734003, 0.01246877],
#        [0.00006102, 0.10280376, 0.89713522],
#        [0.03758632, 0.86869362, 0.09372005],
#        [0.73082985, 0.26417957, 0.00499059],
#        [0.23873122, 0.67820615, 0.08306264],
#        [0.01032077, 0.65948605, 0.33019318],
#        [0.00829703, 0.84934965, 0.14235332],
#        [0.00271815, 0.61407655, 0.3832053 ],
#        [0.56670451, 0.40197582, 0.03131968],
#        [0.92839485, 0.07108374, 0.00052141],
#        [0.00028546, 0.39482539, 0.60488915],
#        [0.00002454, 0.07319603, 0.92677943],
#        [0.68416751, 0.31396353, 0.00186895],
#        [0.00004694, 0.14054425, 0.85940881],
#        [0.92093245, 0.07876532, 0.00030223],
#        [0.94290812, 0.05701676, 0.00007513],
#        [0.22020273, 0.71786137, 0.0619359 ],
#        [0.00016437, 0.27561818, 0.72421745],
#        [0.42802668, 0.53873711, 0.03323621],
#        [0.00120429, 0.2092554 , 0.78954031],
#        [0.00076025, 0.22007476, 0.77916499],
#        [0.02901263, 0.78314549, 0.18784188],
#        [0.00076633, 0.3787677 , 0.62046597],
#        [0.8946671 , 0.10498871, 0.00034418],
#        [0.20474294, 0.77355527, 0.02170179],
#        [0.10747681, 0.83997592, 0.05254727],
#        [0.00165448, 0.45717231, 0.54117321],
#        [0.00863431, 0.49690097, 0.49446472]])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)
 
print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# [[20  3  0]
#  [ 1 34 15]
#  [ 0  5 18]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91        23
#            1       0.81      0.68      0.74        50
#            2       0.55      0.78      0.64        23
#
#     accuracy                           0.75        96
#    macro avg       0.77      0.78      0.76        96
# weighted avg       0.78      0.75      0.76        96
#
# Accuracy of the model:  0.75

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
 
 
print("Classification report:")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91        23
#            1       0.81      0.68      0.74        50
#            2       0.55      0.78      0.64        23
#
#     accuracy                           0.75        96
#    macro avg       0.77      0.78      0.76        96
# weighted avg       0.78      0.75      0.76        96
#
# Accuracy of the model:  0.75

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(classifier.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(classifier.score(X_test, Y_test)))
# Out:
# Training set score: 0.7578
# Test set score: 0.7500

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=10)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()


print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77        23
#            1       0.83      0.60      0.70        50
#            2       0.61      0.96      0.75        23
#
#     accuracy                           0.73        96
#    macro avg       0.73      0.78      0.74        96
# weighted avg       0.76      0.73      0.73        96
#
# Accuracy of the model:  0.7291666666666666

# %%
model_DecisionTree.score(X_train,Y_train)
# Out:
# 0.9973958333333334

# %%
print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.9974
# Test set score: 0.7292

# %%
print(list(zip(data.columns[0:-1],model_DecisionTree.feature_importances_)))
# Out:
# [('gender', np.float64(0.04659080790408169)), ('StageID', np.float64(0.04475200367782753)), ('Relation', np.float64(0.03782980354869803)), ('raisedhands', np.float64(0.14128705922993948)), ('VisITedResources', np.float64(0.24978949957398358)), ('AnnouncementsView', np.float64(0.15716733396986007)), ('Discussion', np.float64(0.0922586971116643)), ('ParentschoolSatisfaction', np.float64(0.014873042610268889)), ('StudentAbsenceDays', np.float64(0.21545175237367642))]

# %%
sample=pd.DataFrame()
sample['Column']=data.columns[0:-1]
sample['Imp value']=model_DecisionTree.feature_importances_
sample.sort_values('Imp value',ascending=False)
# Out:
#                      Column  Imp value
# 4          VisITedResources   0.249789
# 8        StudentAbsenceDays   0.215452
# 5         AnnouncementsView   0.157167
# 3               raisedhands   0.141287
# 6                Discussion   0.092259
# 0                    gender   0.046591
# 1                   StageID   0.044752
# 2                  Relation   0.037830
# 7  ParentschoolSatisfaction   0.014873

# %%
plt.figure(figsize=(30,20))
from sklearn import tree
tree.plot_tree(model_DecisionTree.fit(X_train,Y_train));

# %%
from sklearn import tree
with open(r"model_DecisionTree","w") as f:
    f=tree.export_graphviz(model_DecisionTree,feature_names=data.columns[0:-1],out_file=f)
    # generate the file and upload the code webgraphviz.com to plot the decision tree

# %%
data_new=data.drop(['StageID','ParentschoolSatisfaction','Relation'],axis=1)
data_new
# Out:
#      gender  raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0         1           15                16                  2          20
# 1         1           20                20                  3          25
# 2         1           10                 7                  0          30
# 3         1           30                25                  5          35
# 4         1           40                50                 12          50
# ..      ...          ...               ...                ...         ...
# 475       0            5                 4                  5           8
# 476       0           50                77                 14          28
# 477       0           55                74                 25          29
# 478       0           30                17                 14          57
# 479       0           35                14                 23          62
#
#      StudentAbsenceDays  Class
# 0                     1      1
# 1                     1      1
# 2                     0      0
# 3                     0      0
# 4                     0      1
# ..                  ...    ...
# 475                   0      0
# 476                   1      1
# 477                   1      1
# 478                   0      0
# 479                   0      0
#
# [480 rows x 7 columns]

# %%
# Spliting the data
X_n=data_new.values[:,:-1]
Y_n=data_new.values[:,-1]

# %%
print(X_n.shape)
print(Y_n.shape)
# Out:
# (480, 6)
# (480,)

# %%
from sklearn.preprocessing import StandardScaler
 
scaler = StandardScaler()
 
scaler.fit(X_n)
X_n = scaler.transform(X_n)
#X=scaler.fit_transform(X)
#print(X)

# %%
from sklearn.model_selection import train_test_split
# Split the data into test and train 
X_train,X_test,Y_train,Y_test=train_test_split(X_n,Y_n,test_size=0.2,random_state=42)

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=10)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
 
 
print("Classification report:")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        26
#            1       0.72      0.79      0.75        48
#            2       0.71      0.55      0.62        22
#
#     accuracy                           0.74        96
#    macro avg       0.74      0.71      0.73        96
# weighted avg       0.74      0.74      0.74        96
#
# Accuracy of the model:  0.7395833333333334

# %% [markdown]
# # Overftting in Decision Tree algorithm

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=20,splitter='best',min_samples_leaf=6,max_depth=15)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
 
 
print("Classification report:")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        26
#            1       0.78      0.75      0.77        48
#            2       0.65      0.68      0.67        22
#
#     accuracy                           0.77        96
#    macro avg       0.76      0.77      0.77        96
# weighted avg       0.77      0.77      0.77        96
#
# Accuracy of the model:  0.7708333333333334

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.8307
# Test set score: 0.7708

# %%
# predicting using the Random_Forest_Classifier
from sklearn.ensemble import RandomForestClassifier
model_RandomForest=RandomForestClassifier(n_estimators=100,random_state=10,bootstrap=True)
model_RandomForest.fit(X_train,Y_train)
Y_pred=model_RandomForest.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
 
 
print("Classification report:")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86        26
#            1       0.80      0.73      0.76        48
#            2       0.68      0.68      0.68        22
#
#     accuracy                           0.77        96
#    macro avg       0.76      0.78      0.77        96
# weighted avg       0.77      0.77      0.77        96
#
# Accuracy of the model:  0.7708333333333334

# %%
print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.8307
# Test set score: 0.7708

# %% [markdown]
# # Post Pruning:

# %%
model_RandomForest=RandomForestClassifier( random_state=10, bootstrap=True) #fixed parameters should be passsed here
 
#parameters for trial and error should be passed here
parameter_space = {
    'n_estimators':[100,300,500,1000],       
    'max_depth':[10,15,8, 12],
    'min_samples_leaf':[1,3,4,5,6,7]
    }
from sklearn.model_selection import RandomizedSearchCV #RandomizedSearchCV
clf = RandomizedSearchCV(model_RandomForest, parameter_space, n_jobs=-1, cv=5)

# %%
clf.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=10),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 15, 8, 12],
#                                         'min_samples_leaf': [1, 3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 300, 500, 1000]})

# %%
print('Best parameter found:\n',clf.best_params_)
# Out:
# Best parameter found:
#  {'n_estimators': 1000, 'min_samples_leaf': 5, 'max_depth': 8}

# %%
clf.best_score_
# Out:
# np.float64(0.7316814764183185)

# %%
Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
 
 
print("Classification report:")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87        26
#            1       0.80      0.77      0.79        48
#            2       0.71      0.68      0.70        22
#
#     accuracy                           0.79        96
#    macro avg       0.78      0.79      0.79        96
# weighted avg       0.79      0.79      0.79        96
#
# Accuracy of the model:  0.7916666666666666

# %% [markdown]
# # Handling imbalance data:
